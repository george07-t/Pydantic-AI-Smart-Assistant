# %%
pip install pydantic-ai ollama logfire devtools --upgrade google-api-python-client google-auth-httplib2 google-auth-oauthlib
# Out:
# Requirement already satisfied: pydantic-ai in /home/islam/anaconda3/envs/py311/lib/python3.11/site-packages (0.1.9)
# Requirement already satisfied: ollama in /home/islam/anaconda3/envs/py311/lib/python3.11/site-packages (0.4.8)
# Requirement already satisfied: logfire in /home/islam/anaconda3/envs/py311/lib/python3.11/site-packages (3.14.1)
# Requirement already satisfied: devtools in /home/islam/anaconda3/envs/py311/lib/python3.11/site-packages (0.12.2)
# Requirement already satisfied: google-api-python-client in /home/islam/anaconda3/envs/py311/lib/python3.11/site-packages (2.169.0)
# Requirement already satisfied: google-auth-httplib2 in /home/islam/anaconda3/envs/py311/lib/python3.11/site-packages (0.2.0)
# Requirement already satisfied: google-auth-oauthlib in /home/islam/anaconda3/envs/py311/lib/python3.11/site-packages (1.2.2)
# Requirement already satisfied: pydantic-ai-slim==0.1.9 in /home/islam/anaconda3/envs/py311/lib/python3.11/site-packages (from pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.9->pydantic-ai) (0.1.9)
# Requirement already satisfied: eval-type-backport>=0.2.0 in /home/islam/anaconda3/envs/py311/lib/python3.11/site-packages (from pydantic-ai-slim==0.1.9->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.9->pydantic-ai) (0.2.2)
# Requirement already satisfied: griffe>=1.3.2 in /home/islam/anaconda3/envs/py311/lib/python3.11/site-packages (from pydantic-ai-slim==0.1.9->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.9->pydantic-ai) (1.7.3)
# Requirement already satisfied: httpx>=0.27 in /home/islam/anaconda3/envs/py311/lib/python3.11/site-packages (from pydantic-ai-slim==0.1.9->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.9->pydantic-ai) (0.28.1)
# Requirement already satisfied: opentelemetry-api>=1.28.0 in /home/islam/anaconda3/envs/py311/lib/python3.11/site-packages (from pydantic-ai-slim==0.1.9->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.9->pydantic-ai) (1.32.1)
# Requirement already satisfied: pydantic-graph==0.1.9 in /home/islam/anaconda3/envs/py311/lib/python3.11/site-packages (from pydantic-ai-slim==0.1.9->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.9->pydantic-ai) (0.1.9)
# Requirement already satisfied: pydantic>=2.10 in /home/islam/anaconda3/envs/py311/lib/python3.11/site-packages (from pydantic-ai-slim==0.1.9->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.9->pydantic-ai) (2.11.4)
# Requirement already satisfied: typing-inspection>=0.4.0 in /home/islam/anaconda3/envs/py311/lib/python3.11/site-packages (from pydantic-ai-slim==0.1.9->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.9->pydantic-ai) (0.4.0)
# Requirement already satisfied: anthropic>=0.49.0 in /home/islam/anaconda3/envs/py311/lib/python3.11/site-packages (from pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.9->pydantic-ai) (0.50.0)
# Requirement already satisfied: boto3>=1.35.74 in /home/islam/anaconda3/envs/py311/lib/python3.11/site-packages (from pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.9->pydantic-ai) (1.38.8)
# Requirement already satisfied: argcomplete>=3.5.0 in /home/islam/anaconda3/envs/py311/lib/python3.11/site-packages (from pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.9->pydantic-ai) (3.6.2)
# Requirement already satisfied: prompt-toolkit>=3 in /home/islam/anaconda3/envs/py311/lib/python3.11/site-packages (from pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.9->pydantic-ai) (3.0.43)
# Requirement already satisfied: rich>=13 in /home/islam/anaconda3/envs/py311/lib/python3.11/site-packages (from pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.9->pydantic-ai) (13.9.4)
# Requirement already satisfied: cohere>=5.13.11 in /home/islam/anaconda3/envs/py311/lib/python3.11/site-packages (from pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.9->pydantic-ai) (5.15.0)
# Requirement already satisfied: pydantic-evals==0.1.9 in /home/islam/anaconda3/envs/py311/lib/python3.11/site-packages (from pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.9->pydantic-ai) (0.1.9)
# Requirement already satisfied: groq>=0.15.0 in /home/islam/anaconda3/envs/py311/lib/python3.11/site-packages (from pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.9->pydantic-ai) (0.24.0)
# Requirement already satisfied: mcp>=1.6.0 in /home/islam/anaconda3/envs/py311/lib/python3.11/site-packages (from pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.9->pydantic-ai) (1.7.1)
# Requirement already satisfied: mistralai>=1.2.5 in /home/islam/anaconda3/envs/py311/lib/python3.11/site-packages (from pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.9->pydantic-ai) (1.7.0)
# Requirement already satisfied: openai>=1.75.0 in /home/islam/anaconda3/envs/py311/lib/python3.11/site-packages (from pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.9->pydantic-ai) (1.77.0)
# Requirement already satisfied: google-auth>=2.36.0 in /home/islam/anaconda3/envs/py311/lib/python3.11/site-packages (from pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.9->pydantic-ai) (2.39.0)
# Requirement already satisfied: requests>=2.32.2 in /home/islam/anaconda3/envs/py311/lib/python3.11/site-packages (from pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.9->pydantic-ai) (2.32.3)
# Requirement already satisfied: anyio>=0 in /home/islam/anaconda3/envs/py311/lib/python3.11/site-packages (from pydantic-evals==0.1.9->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.9->pydantic-ai) (4.9.0)
# Requirement already satisfied: logfire-api>=1.2.0 in /home/islam/anaconda3/envs/py311/lib/python3.11/site-packages (from pydantic-evals==0.1.9->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.9->pydantic-ai) (3.14.1)
# Requirement already satisfied: pyyaml>=6.0.2 in /home/islam/anaconda3/envs/py311/lib/python3.11/site-packages (from pydantic-evals==0.1.9->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.9->pydantic-ai) (6.0.2)
# Requirement already satisfied: executing>=2.0.1 in /home/islam/anaconda3/envs/py311/lib/python3.11/site-packages (from logfire) (2.2.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http<1.33.0,>=1.21.0 in /home/islam/anaconda3/envs/py311/lib/python3.11/site-packages (from logfire) (1.32.1)
# Requirement already satisfied: opentelemetry-instrumentation>=0.41b0 in /home/islam/anaconda3/envs/py311/lib/python3.11/site-packages (from logfire) (0.53b1)
# Requirement already satisfied: opentelemetry-sdk<1.33.0,>=1.21.0 in /home/islam/anaconda3/envs/py311/lib/python3.11/site-packages (from logfire) (1.32.1)
# Requirement already satisfied: protobuf>=4.23.4 in /home/islam/anaconda3/envs/py311/lib/python3.11/site-packages (from logfire) (5.28.3)
# Requirement already satisfied: typing-extensions>=4.1.0 in /home/islam/anaconda3/envs/py311/lib/python3.11/site-packages (from logfire) (4.13.2)
# Requirement already satisfied: asttokens<3.0.0,>=2.0.0 in /home/islam/anaconda3/envs/py311/lib/python3.11/site-packages (from devtools) (2.0.5)
# Requirement already satisfied: pygments>=2.15.0 in /home/islam/anaconda3/envs/py311/lib/python3.11/site-packages (from devtools) (2.15.1)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in /home/islam/anaconda3/envs/py311/lib/python3.11/site-packages (from google-api-python-client) (0.22.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5 in /home/islam/anaconda3/envs/py311/lib/python3.11/site-packages (from google-api-python-client) (2.24.2)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /home/islam/anaconda3/envs/py311/lib/python3.11/site-packages (from google-api-python-client) (4.1.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/islam/anaconda3/envs/py311/lib/python3.11/site-packages (from google-auth-oauthlib) (2.0.0)
# Requirement already satisfied: six in /home/islam/anaconda3/envs/py311/lib/python3.11/site-packages (from asttokens<3.0.0,>=2.0.0->devtools) (1.16.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /home/islam/anaconda3/envs/py311/lib/python3.11/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (1.70.0)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /home/islam/anaconda3/envs/py311/lib/python3.11/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (1.26.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/islam/anaconda3/envs/py311/lib/python3.11/site-packages (from google-auth>=2.36.0->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.9->pydantic-ai) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/islam/anaconda3/envs/py311/lib/python3.11/site-packages (from google-auth>=2.36.0->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.9->pydantic-ai) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/islam/anaconda3/envs/py311/lib/python3.11/site-packages (from google-auth>=2.36.0->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.9->pydantic-ai) (4.9.1)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /home/islam/anaconda3/envs/py311/lib/python3.11/site-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client) (3.2.0)
# Requirement already satisfied: certifi in /home/islam/anaconda3/envs/py311/lib/python3.11/site-packages (from httpx>=0.27->pydantic-ai-slim==0.1.9->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.9->pydantic-ai) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /home/islam/anaconda3/envs/py311/lib/python3.11/site-packages (from httpx>=0.27->pydantic-ai-slim==0.1.9->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.9->pydantic-ai) (1.0.2)
# Requirement already satisfied: idna in /home/islam/anaconda3/envs/py311/lib/python3.11/site-packages (from httpx>=0.27->pydantic-ai-slim==0.1.9->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.9->pydantic-ai) (3.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/islam/anaconda3/envs/py311/lib/python3.11/site-packages (from httpcore==1.*->httpx>=0.27->pydantic-ai-slim==0.1.9->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.9->pydantic-ai) (0.14.0)
# Requirement already satisfied: deprecated>=1.2.6 in /home/islam/anaconda3/envs/py311/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-http<1.33.0,>=1.21.0->logfire) (1.2.18)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.32.1 in /home/islam/anaconda3/envs/py311/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-http<1.33.0,>=1.21.0->logfire) (1.32.1)
# Requirement already satisfied: opentelemetry-proto==1.32.1 in /home/islam/anaconda3/envs/py311/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-http<1.33.0,>=1.21.0->logfire) (1.32.1)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.53b1 in /home/islam/anaconda3/envs/py311/lib/python3.11/site-packages (from opentelemetry-instrumentation>=0.41b0->logfire) (0.53b1)
# Requirement already satisfied: packaging>=18.0 in /home/islam/anaconda3/envs/py311/lib/python3.11/site-packages (from opentelemetry-instrumentation>=0.41b0->logfire) (24.1)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in /home/islam/anaconda3/envs/py311/lib/python3.11/site-packages (from opentelemetry-instrumentation>=0.41b0->logfire) (1.17.0)
# Requirement already satisfied: importlib-metadata<8.7.0,>=6.0 in /home/islam/anaconda3/envs/py311/lib/python3.11/site-packages (from opentelemetry-api>=1.28.0->pydantic-ai-slim==0.1.9->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.9->pydantic-ai) (8.6.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/islam/anaconda3/envs/py311/lib/python3.11/site-packages (from pydantic>=2.10->pydantic-ai-slim==0.1.9->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.9->pydantic-ai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /home/islam/anaconda3/envs/py311/lib/python3.11/site-packages (from pydantic>=2.10->pydantic-ai-slim==0.1.9->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.9->pydantic-ai) (2.33.2)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/islam/anaconda3/envs/py311/lib/python3.11/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib) (3.2.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/islam/anaconda3/envs/py311/lib/python3.11/site-packages (from rich>=13->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.9->pydantic-ai) (3.0.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /home/islam/anaconda3/envs/py311/lib/python3.11/site-packages (from anthropic>=0.49.0->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.9->pydantic-ai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /home/islam/anaconda3/envs/py311/lib/python3.11/site-packages (from anthropic>=0.49.0->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.9->pydantic-ai) (0.9.0)
# Requirement already satisfied: sniffio in /home/islam/anaconda3/envs/py311/lib/python3.11/site-packages (from anthropic>=0.49.0->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.9->pydantic-ai) (1.3.0)
# Requirement already satisfied: botocore<1.39.0,>=1.38.8 in /home/islam/anaconda3/envs/py311/lib/python3.11/site-packages (from boto3>=1.35.74->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.9->pydantic-ai) (1.38.8)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /home/islam/anaconda3/envs/py311/lib/python3.11/site-packages (from boto3>=1.35.74->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.9->pydantic-ai) (1.0.1)
# Requirement already satisfied: s3transfer<0.13.0,>=0.12.0 in /home/islam/anaconda3/envs/py311/lib/python3.11/site-packages (from boto3>=1.35.74->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.9->pydantic-ai) (0.12.0)
# Requirement already satisfied: fastavro<2.0.0,>=1.9.4 in /home/islam/anaconda3/envs/py311/lib/python3.11/site-packages (from cohere>=5.13.11->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.9->pydantic-ai) (1.10.0)
# Requirement already satisfied: httpx-sse==0.4.0 in /home/islam/anaconda3/envs/py311/lib/python3.11/site-packages (from cohere>=5.13.11->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.9->pydantic-ai) (0.4.0)
# Requirement already satisfied: tokenizers<1,>=0.15 in /home/islam/anaconda3/envs/py311/lib/python3.11/site-packages (from cohere>=5.13.11->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.9->pydantic-ai) (0.21.1)
# Requirement already satisfied: types-requests<3.0.0,>=2.0.0 in /home/islam/anaconda3/envs/py311/lib/python3.11/site-packages (from cohere>=5.13.11->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.9->pydantic-ai) (2.32.0.20250328)
# Requirement already satisfied: colorama>=0.4 in /home/islam/anaconda3/envs/py311/lib/python3.11/site-packages (from griffe>=1.3.2->pydantic-ai-slim==0.1.9->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.9->pydantic-ai) (0.4.6)
# Requirement already satisfied: mdurl~=0.1 in /home/islam/anaconda3/envs/py311/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich>=13->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.9->pydantic-ai) (0.1.2)
# Requirement already satisfied: pydantic-settings>=2.5.2 in /home/islam/anaconda3/envs/py311/lib/python3.11/site-packages (from mcp>=1.6.0->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.9->pydantic-ai) (2.9.1)
# Requirement already satisfied: python-multipart>=0.0.9 in /home/islam/anaconda3/envs/py311/lib/python3.11/site-packages (from mcp>=1.6.0->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.9->pydantic-ai) (0.0.20)
# Requirement already satisfied: sse-starlette>=1.6.1 in /home/islam/anaconda3/envs/py311/lib/python3.11/site-packages (from mcp>=1.6.0->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.9->pydantic-ai) (2.3.4)
# Requirement already satisfied: starlette>=0.27 in /home/islam/anaconda3/envs/py311/lib/python3.11/site-packages (from mcp>=1.6.0->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.9->pydantic-ai) (0.41.3)
# Requirement already satisfied: uvicorn>=0.23.1 in /home/islam/anaconda3/envs/py311/lib/python3.11/site-packages (from mcp>=1.6.0->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.9->pydantic-ai) (0.32.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/islam/anaconda3/envs/py311/lib/python3.11/site-packages (from mistralai>=1.2.5->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.9->pydantic-ai) (2.9.0.post0)
# Requirement already satisfied: tqdm>4 in /home/islam/anaconda3/envs/py311/lib/python3.11/site-packages (from openai>=1.75.0->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.9->pydantic-ai) (4.65.0)
# Requirement already satisfied: wcwidth in /home/islam/anaconda3/envs/py311/lib/python3.11/site-packages (from prompt-toolkit>=3->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.9->pydantic-ai) (0.2.5)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /home/islam/anaconda3/envs/py311/lib/python3.11/site-packages (from pyasn1-modules>=0.2.1->google-auth>=2.36.0->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.9->pydantic-ai) (0.6.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/islam/anaconda3/envs/py311/lib/python3.11/site-packages (from requests>=2.32.2->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.9->pydantic-ai) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/islam/anaconda3/envs/py311/lib/python3.11/site-packages (from requests>=2.32.2->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.9->pydantic-ai) (2.2.3)
# Requirement already satisfied: zipp>=3.20 in /home/islam/anaconda3/envs/py311/lib/python3.11/site-packages (from importlib-metadata<8.7.0,>=6.0->opentelemetry-api>=1.28.0->pydantic-ai-slim==0.1.9->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.9->pydantic-ai) (3.21.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in /home/islam/anaconda3/envs/py311/lib/python3.11/site-packages (from pydantic-settings>=2.5.2->mcp>=1.6.0->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.9->pydantic-ai) (1.1.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /home/islam/anaconda3/envs/py311/lib/python3.11/site-packages (from tokenizers<1,>=0.15->cohere>=5.13.11->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.9->pydantic-ai) (0.30.2)
# Requirement already satisfied: click>=7.0 in /home/islam/anaconda3/envs/py311/lib/python3.11/site-packages (from uvicorn>=0.23.1->mcp>=1.6.0->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.9->pydantic-ai) (8.1.8)
# Requirement already satisfied: filelock in /home/islam/anaconda3/envs/py311/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<1,>=0.15->cohere>=5.13.11->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.9->pydantic-ai) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/islam/anaconda3/envs/py311/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<1,>=0.15->cohere>=5.13.11->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.9->pydantic-ai) (2024.10.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import re
import os
from dataclasses import dataclass
from typing import Any
from datetime import datetime
import requests
import gradio as gr
import nest_asyncio
from dotenv import load_dotenv
from httpx import AsyncClient
from google_auth_oauthlib.flow import InstalledAppFlow
from googleapiclient.discovery import build
from google.auth.transport.requests import Request
from google.oauth2.credentials import Credentials
from datetime import datetime
from pydantic_ai import Agent, ModelRetry, RunContext
from pydantic_ai.models.openai import OpenAIModel
from pydantic_ai.providers.openai import OpenAIProvider
from datetime import datetime, timedelta
from google_auth_oauthlib.flow import InstalledAppFlow
from googleapiclient.discovery import build
from google.auth.transport.requests import Request
from google.oauth2.credentials import Credentials

# ---------- Setup ----------
load_dotenv()
nest_asyncio.apply()

ollama_model = OpenAIModel(
    model_name='qwen2.5:latest',
    provider=OpenAIProvider(base_url='http://localhost:11434/v1')
)


@dataclass
class Deps:
    client: AsyncClient
    weather_api_key: str | None


agent = Agent(
    ollama_model,
    system_prompt=(
        'You are a smart assistant. You can access tools:\n'
        '- get_weather(city: str): Returns weather info.\n'
        '- calculate_expression(expression: str): Evaluates math.\n'
        '- tripPlanner(start_date: date, end_date: date, location: str): Trip planner.\n'
        '- add_to_google_calendar(summary, location, start_date, end_date): Adds to Google Calendar.\n'
        '- get_upcoming_events(start_date, end_date): Retrieves upcoming events.\n'
        'Use these tools when the user requests relevant information.'
    ),
    deps_type=Deps,
    retries=2,
    instrument=True,
)


trip_agent = Agent(
    ollama_model,
    output_type=str,)

# %%
import httpx


async def fetch_wikipedia_summary(location: str) -> str:
    try:
        async with httpx.AsyncClient() as client:
            response = await client.get(f"https://en.wikipedia.org/api/rest_v1/page/summary/{location}")
            if response.status_code == 200:
                return response.json().get("extract", "")
    except:
        return ""


def is_valid_expression(expr: str) -> bool:
    return bool(re.fullmatch(r"[0-9+\-*/().\\s]+", expr.strip()))


@agent.tool
async def get_weather(context: RunContext[Deps], city: str) -> str:
    """
    Fetches the current weather temperature for a specified city using the WeatherAPI.

    Args:
        city (str): The name of the city for which to fetch the weather.

    Returns:
        str: A message containing the current temperature in Celsius for the specified city, 
             or an error message if the city is not found or the API response is invalid.

    Example:
        >>> get_weather("Dhaka")
        'The current temperature in Dhaka is 30°C.'
    """
    if not context.deps.weather_api_key:
        raise ValueError("Weather API key is not set.")

    url = f"http://api.weatherapi.com/v1/current.json?key={context.deps.weather_api_key}&q={city}"
    response = await context.deps.client.get(url)
    data = response.json()
    print(f"Tool Get_weather: {data}")
    return f"The weather in {city} is {data['current']['temp_c']}\u00b0C."


@agent.tool_plain
async def calculate_expression(expression: str) -> str:
    """
    Evaluates a mathematical expression provided as a string.

    Args:
        expression (str): A string containing a mathematical expression to be evaluated.

    Returns:
        str: The result of the evaluation as a string, or an error message if the evaluation fails.

    Example:
        >>> calculate_expression("2 + 3 * 4")
        '14'
        >>> calculate_expression("10 / 0")
        'Calculation error: division by zero'
    """
    if not is_valid_expression(expression):
        raise ModelRetry('This does not look like a valid math expression.')
    try:
        print(f"Tool Calculate_expression: {expression}")
        return str(eval(expression))
    except Exception as e:
        return f"Calculation error: {e}"


@agent.tool_plain
async def tripPlanner(start_date: str, end_date: str, location: str) -> str:
    try:
        start = datetime.strptime(start_date, "%Y-%m-%d")
        end = datetime.strptime(end_date, "%Y-%m-%d")
        duration = (end - start).days + 1
        today = datetime.now().date()
        if start.date() < today:
            return "❌ The start date cannot be in the past."
        if end.date() < today:
            return "❌ The end date cannot be in the past."
        if end.date() <= start.date():
            return "❌ The end date must be after the start date."

        if duration <= 0:
            return "Invalid date range. Please check the start and end dates."

        contexts = await fetch_wikipedia_summary(location)

        prompt = (
            f"Context:\n{contexts}\n\n"
            f"I'm planning a {duration}-day trip to {location}. "
            f"Give me the following:\n"
            f"- Famous attractions\n"
            f"- Food recommendations\n"
            f"- Fun activities\n"
            f"- A fun fact\n"
            f"- Estimated budget (in local currency)\n"
            f"Keep it concise and friendly."
        )

        response = await trip_agent.run(
            prompt,
        )
        print(f"toolPlanner")
        return response.output

    except ValueError:
        return "Please use YYYY-MM-DD format for dates."
    except Exception as e:
        return f"Error: {e}"


@agent.tool_plain
async def add_to_google_calendar(summary: str, location: str, start_date: str, end_date: str) -> str:
    """
    Adds an event to Google Calendar with the provided details.

    Args:
        summary (str): The title/summary of the event.
        location (str): The location of the event.
        start_date (str): The start date of the event in 'YYYY-MM-DD' format.
        end_date (str): The end date of the event in 'YYYY-MM-DD' format.

    Returns:
        str: A confirmation message with the event link, or an error message.

    Example:
        >>> add_to_google_calendar("Trip to Sylhet", "Sylhet", "2024-06-01", "2024-06-05")
        '✅ Trip added to your Google Calendar: https://calendar.google.com/event?eid=...'
    """

    # Validate dates are not in the past
    current_datetime = datetime.now()

    # Parse start and end dates
    start_datetime = datetime.strptime(
        f'{start_date}T09:00:00', '%Y-%m-%dT%H:%M:%S')
    end_datetime = datetime.strptime(
        f'{end_date}T17:00:00', '%Y-%m-%dT%H:%M:%S')

    if start_datetime < current_datetime:
        return "❌ The start date cannot be in the past."
    if end_datetime < current_datetime:
        return "❌ The end date cannot be in the past."
    if end_datetime <= start_datetime:
        return "❌ The end date must be after the start date."

    # Google Calendar API setup
    SCOPES = ['https://www.googleapis.com/auth/calendar.events']

    creds = None
    if os.path.exists('token.json'):
        creds = Credentials.from_authorized_user_file('token.json', SCOPES)
    if not creds or not creds.valid:
        if creds and creds.expired and creds.refresh_token:
            creds.refresh(Request())
        else:
            flow = InstalledAppFlow.from_client_secrets_file(
                'credentials.json', SCOPES)
            creds = flow.run_local_server(port=0)
        with open('token.json', 'w') as token:
            token.write(creds.to_json())

    service = build('calendar', 'v3', credentials=creds)

    event = {
        'summary': summary,
        'location': location,
        'start': {
            'dateTime': f'{start_date}T09:00:00',
            'timeZone': 'Asia/Dhaka',
        },
        'end': {
            'dateTime': f'{end_date}T17:00:00',
            'timeZone': 'Asia/Dhaka',
        },
        'description': f'Trip to {location} from {start_date} to {end_date}. Auto-generated by AI.'
    }

    # Create the event on Google Calendar
    event = service.events().insert(calendarId='primary', body=event).execute()
    print(f"Event created: {event.get('htmlLink')}")

    return f"✅ Trip added to your Google Calendar: {event.get('htmlLink')}"


@agent.tool_plain
async def get_upcoming_events(start_date=None, end_date=None):
    """
    Retrieves upcoming Google Calendar events within a given date range if given else retrives next one month events from today.

    Args:
        start_date (str, optional): Start date in 'YYYY-MM-DD' format or 'today'. Defaults to today.
        end_date (str, optional): End date in 'YYYY-MM-DD' format. Defaults to 1 month from today.

    Returns:
        str: A list of upcoming events with date, time, and summary.

    Example:
        >>> get_upcoming_events("2024-06-01", "2024-06-15")
        '📅 June 2, 10:00 AM - Team Meeting\n📅 June 5, 3:00 PM - Doctor Appointment\n...'
    """

    SCOPES = ['https://www.googleapis.com/auth/calendar.readonly']

    # Auth setup
    creds = None
    if os.path.exists('token.json'):
        creds = Credentials.from_authorized_user_file('token.json', SCOPES)
    if not creds or not creds.valid:
        if creds and creds.expired and creds.refresh_token:
            creds.refresh(Request())
        else:
            flow = InstalledAppFlow.from_client_secrets_file(
                'credentials.json', SCOPES)
            creds = flow.run_local_server(port=0)
        with open('token.json', 'w') as token:
            token.write(creds.to_json())

    service = build('calendar', 'v3', credentials=creds)

    # Default date range: today to 30 days later
    now = datetime.utcnow()

    if start_date == "today" or not start_date:
        time_min = now
    else:
        time_min = datetime.strptime(start_date, '%Y-%m-%d')

    if end_date:
        time_max = datetime.strptime(end_date, '%Y-%m-%d')
    else:
        time_max = now + timedelta(days=30)

    time_min_str = time_min.isoformat() + 'Z'
    time_max_str = time_max.isoformat() + 'Z'

    # Fetch events
    events_result = service.events().list(
        calendarId='primary',
        timeMin=time_min_str,
        timeMax=time_max_str,
        singleEvents=True,
        orderBy='startTime'
    ).execute()

    events = events_result.get('items', [])

    if not events:
        return "📭 No upcoming events found in the selected date range."

    result = []
    for event in events:
        start = event['start'].get('dateTime', event['start'].get('date'))
        start_dt = datetime.fromisoformat(start.replace('Z', '+00:00'))
        start_formatted = start_dt.strftime("📅 %B %d, %I:%M %p")
        summary = event.get('summary', '(No Title)')
        result.append(f"{start_formatted} - {summary}")

    print(f"Upcoming events:")
    return "\n".join(result)

# %%
# ---------- Gradio Setup ----------
chat_messages = []  # Global message history


async def chat_with_agent(message, history):
    weather_key = os.getenv('weatherapicom_API_KEY')
    async with AsyncClient() as client:
        deps = Deps(client=client, weather_api_key=weather_key)
        global chat_messages

        # Prepare conversation
        if not chat_messages:
            result = await agent.run(message, deps=deps)
        else:
            result = await agent.run(message, deps=deps, message_history=chat_messages)

        chat_messages = result.new_messages()

        # Process the result to check if a tool was called and format the output
        tool_output = result.output

        if "🔧 Called" in tool_output:  # Check if the output contains tool call info
            # Split the tool output into the tool call and result parts
            # Split into 3 parts: tool call, result, and assistant's response
            parts = tool_output.split("\n", 2)
            tool_call = parts[0]  # Tool call
            result_part = parts[1]  # Result part
            assistant_response = parts[2] if len(
                parts) > 2 else "No additional response."

            # Combine the tool call and result with the assistant's final response
            formatted_response = f"{tool_call}\n{result_part}\n🤖 {assistant_response}"

        else:
            # If no tool was called, just return the assistant's output
            formatted_response = f"🤖 {tool_output}"

        return "", history + [[message, formatted_response]]


def reset_chat():
    global chat_messages
    chat_messages = []
    return [], ""


with gr.Blocks() as demo:
    gr.Markdown("## 🤖 Smart Assistant with Tools")

    chatbot = gr.Chatbot()
    msg = gr.Textbox(label="Ask me something...")
    clear = gr.Button("Clear Chat")

    msg.submit(chat_with_agent, [msg, chatbot], [msg, chatbot])
    clear.click(reset_chat, outputs=[chatbot, msg])
    demo.unload(reset_chat)

# ---------- Launch ----------
demo.launch(share=True)
# Out:
# /tmp/ipykernel_1157270/2673451760.py:50: UserWarning: You have not specified a value for the `type` parameter. Defaulting to the 'tuples' format for chatbot messages, but this is deprecated and will be removed in a future version of Gradio. Please set type='messages' instead, which uses openai-style dictionaries with 'role' and 'content' keys.
#   chatbot = gr.Chatbot()
# * Running on local URL:  http://127.0.0.1:7863
# * Running on public URL: https://f99e530f289db3eab6.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://f99e530f289db3eab6.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Upcoming events:
