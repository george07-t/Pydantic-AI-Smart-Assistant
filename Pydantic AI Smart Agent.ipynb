# %%
pip install pydantic-ai ollama logfire devtools googlesearch-python
# Out:
# Requirement already satisfied: pydantic-ai in /home/islam/.local/lib/python3.11/site-packages (0.1.10)
# Requirement already satisfied: ollama in /home/islam/anaconda3/envs/py311/lib/python3.11/site-packages (0.4.8)
# Requirement already satisfied: logfire in /home/islam/.local/lib/python3.11/site-packages (3.14.1)
# Requirement already satisfied: devtools in /home/islam/anaconda3/envs/py311/lib/python3.11/site-packages (0.12.2)
# Requirement already satisfied: googlesearch-python in /home/islam/anaconda3/envs/py311/lib/python3.11/site-packages (1.3.0)
# Requirement already satisfied: pydantic-ai-slim==0.1.10 in /home/islam/.local/lib/python3.11/site-packages (from pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.10->pydantic-ai) (0.1.10)
# Requirement already satisfied: eval-type-backport>=0.2.0 in /home/islam/.local/lib/python3.11/site-packages (from pydantic-ai-slim==0.1.10->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.10->pydantic-ai) (0.2.2)
# Requirement already satisfied: griffe>=1.3.2 in /home/islam/.local/lib/python3.11/site-packages (from pydantic-ai-slim==0.1.10->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.10->pydantic-ai) (1.7.3)
# Requirement already satisfied: httpx>=0.27 in /home/islam/.local/lib/python3.11/site-packages (from pydantic-ai-slim==0.1.10->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.10->pydantic-ai) (0.28.1)
# Requirement already satisfied: opentelemetry-api>=1.28.0 in /home/islam/.local/lib/python3.11/site-packages (from pydantic-ai-slim==0.1.10->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.10->pydantic-ai) (1.32.1)
# Requirement already satisfied: pydantic-graph==0.1.10 in /home/islam/.local/lib/python3.11/site-packages (from pydantic-ai-slim==0.1.10->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.10->pydantic-ai) (0.1.10)
# Requirement already satisfied: pydantic>=2.10 in /home/islam/.local/lib/python3.11/site-packages (from pydantic-ai-slim==0.1.10->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.10->pydantic-ai) (2.11.4)
# Requirement already satisfied: typing-inspection>=0.4.0 in /home/islam/.local/lib/python3.11/site-packages (from pydantic-ai-slim==0.1.10->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.10->pydantic-ai) (0.4.0)
# Requirement already satisfied: anthropic>=0.49.0 in /home/islam/.local/lib/python3.11/site-packages (from pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.10->pydantic-ai) (0.50.0)
# Requirement already satisfied: boto3>=1.35.74 in /home/islam/.local/lib/python3.11/site-packages (from pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.10->pydantic-ai) (1.38.10)
# Requirement already satisfied: argcomplete>=3.5.0 in /home/islam/.local/lib/python3.11/site-packages (from pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.10->pydantic-ai) (3.6.2)
# Requirement already satisfied: prompt-toolkit>=3 in /home/islam/.local/lib/python3.11/site-packages (from pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.10->pydantic-ai) (3.0.51)
# Requirement already satisfied: rich>=13 in /home/islam/.local/lib/python3.11/site-packages (from pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.10->pydantic-ai) (14.0.0)
# Requirement already satisfied: cohere>=5.13.11 in /home/islam/.local/lib/python3.11/site-packages (from pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.10->pydantic-ai) (5.15.0)
# Requirement already satisfied: pydantic-evals==0.1.10 in /home/islam/.local/lib/python3.11/site-packages (from pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.10->pydantic-ai) (0.1.10)
# Requirement already satisfied: groq>=0.15.0 in /home/islam/.local/lib/python3.11/site-packages (from pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.10->pydantic-ai) (0.24.0)
# Requirement already satisfied: mcp>=1.6.0 in /home/islam/.local/lib/python3.11/site-packages (from pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.10->pydantic-ai) (1.7.1)
# Requirement already satisfied: mistralai>=1.2.5 in /home/islam/.local/lib/python3.11/site-packages (from pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.10->pydantic-ai) (1.7.0)
# Requirement already satisfied: openai>=1.75.0 in /home/islam/anaconda3/envs/py311/lib/python3.11/site-packages (from pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.10->pydantic-ai) (1.75.0)
# Requirement already satisfied: google-auth>=2.36.0 in /home/islam/.local/lib/python3.11/site-packages (from pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.10->pydantic-ai) (2.40.1)
# Requirement already satisfied: requests>=2.32.2 in /home/islam/.local/lib/python3.11/site-packages (from pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.10->pydantic-ai) (2.32.3)
# Requirement already satisfied: anyio>=0 in /home/islam/.local/lib/python3.11/site-packages (from pydantic-evals==0.1.10->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.10->pydantic-ai) (4.9.0)
# Requirement already satisfied: logfire-api>=1.2.0 in /home/islam/.local/lib/python3.11/site-packages (from pydantic-evals==0.1.10->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.10->pydantic-ai) (3.14.1)
# Requirement already satisfied: pyyaml>=6.0.2 in /home/islam/.local/lib/python3.11/site-packages (from pydantic-evals==0.1.10->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.10->pydantic-ai) (6.0.2)
# Requirement already satisfied: executing>=2.0.1 in /home/islam/.local/lib/python3.11/site-packages (from logfire) (2.2.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http<1.33.0,>=1.21.0 in /home/islam/.local/lib/python3.11/site-packages (from logfire) (1.32.1)
# Requirement already satisfied: opentelemetry-instrumentation>=0.41b0 in /home/islam/.local/lib/python3.11/site-packages (from logfire) (0.53b1)
# Requirement already satisfied: opentelemetry-sdk<1.33.0,>=1.21.0 in /home/islam/.local/lib/python3.11/site-packages (from logfire) (1.32.1)
# Requirement already satisfied: protobuf>=4.23.4 in /home/islam/.local/lib/python3.11/site-packages (from logfire) (5.29.4)
# Requirement already satisfied: typing-extensions>=4.1.0 in /home/islam/.local/lib/python3.11/site-packages (from logfire) (4.13.2)
# Requirement already satisfied: asttokens<3.0.0,>=2.0.0 in /home/islam/anaconda3/envs/py311/lib/python3.11/site-packages (from devtools) (2.0.5)
# Requirement already satisfied: pygments>=2.15.0 in /home/islam/.local/lib/python3.11/site-packages (from devtools) (2.19.1)
# Requirement already satisfied: beautifulsoup4>=4.9 in /home/islam/anaconda3/envs/py311/lib/python3.11/site-packages (from googlesearch-python) (4.12.3)
# Requirement already satisfied: six in /home/islam/anaconda3/envs/py311/lib/python3.11/site-packages (from asttokens<3.0.0,>=2.0.0->devtools) (1.16.0)
# Requirement already satisfied: soupsieve>1.2 in /home/islam/anaconda3/envs/py311/lib/python3.11/site-packages (from beautifulsoup4>=4.9->googlesearch-python) (2.5)
# Requirement already satisfied: certifi in /home/islam/anaconda3/envs/py311/lib/python3.11/site-packages (from httpx>=0.27->pydantic-ai-slim==0.1.10->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.10->pydantic-ai) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /home/islam/.local/lib/python3.11/site-packages (from httpx>=0.27->pydantic-ai-slim==0.1.10->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.10->pydantic-ai) (1.0.9)
# Requirement already satisfied: idna in /home/islam/anaconda3/envs/py311/lib/python3.11/site-packages (from httpx>=0.27->pydantic-ai-slim==0.1.10->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.10->pydantic-ai) (3.7)
# Requirement already satisfied: h11>=0.16 in /home/islam/.local/lib/python3.11/site-packages (from httpcore==1.*->httpx>=0.27->pydantic-ai-slim==0.1.10->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.10->pydantic-ai) (0.16.0)
# Requirement already satisfied: deprecated>=1.2.6 in /home/islam/.local/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-http<1.33.0,>=1.21.0->logfire) (1.2.18)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /home/islam/.local/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-http<1.33.0,>=1.21.0->logfire) (1.70.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.32.1 in /home/islam/.local/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-http<1.33.0,>=1.21.0->logfire) (1.32.1)
# Requirement already satisfied: opentelemetry-proto==1.32.1 in /home/islam/.local/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-http<1.33.0,>=1.21.0->logfire) (1.32.1)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.53b1 in /home/islam/.local/lib/python3.11/site-packages (from opentelemetry-instrumentation>=0.41b0->logfire) (0.53b1)
# Requirement already satisfied: packaging>=18.0 in /home/islam/.local/lib/python3.11/site-packages (from opentelemetry-instrumentation>=0.41b0->logfire) (25.0)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in /home/islam/.local/lib/python3.11/site-packages (from opentelemetry-instrumentation>=0.41b0->logfire) (1.17.2)
# Requirement already satisfied: importlib-metadata<8.7.0,>=6.0 in /home/islam/.local/lib/python3.11/site-packages (from opentelemetry-api>=1.28.0->pydantic-ai-slim==0.1.10->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.10->pydantic-ai) (8.6.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/islam/.local/lib/python3.11/site-packages (from pydantic>=2.10->pydantic-ai-slim==0.1.10->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.10->pydantic-ai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /home/islam/.local/lib/python3.11/site-packages (from pydantic>=2.10->pydantic-ai-slim==0.1.10->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.10->pydantic-ai) (2.33.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/islam/.local/lib/python3.11/site-packages (from requests>=2.32.2->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.10->pydantic-ai) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/islam/.local/lib/python3.11/site-packages (from requests>=2.32.2->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.10->pydantic-ai) (2.4.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/islam/.local/lib/python3.11/site-packages (from rich>=13->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.10->pydantic-ai) (3.0.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /home/islam/anaconda3/envs/py311/lib/python3.11/site-packages (from anthropic>=0.49.0->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.10->pydantic-ai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /home/islam/.local/lib/python3.11/site-packages (from anthropic>=0.49.0->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.10->pydantic-ai) (0.9.0)
# Requirement already satisfied: sniffio in /home/islam/.local/lib/python3.11/site-packages (from anthropic>=0.49.0->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.10->pydantic-ai) (1.3.1)
# Requirement already satisfied: botocore<1.39.0,>=1.38.10 in /home/islam/.local/lib/python3.11/site-packages (from boto3>=1.35.74->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.10->pydantic-ai) (1.38.10)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /home/islam/.local/lib/python3.11/site-packages (from boto3>=1.35.74->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.10->pydantic-ai) (1.0.1)
# Requirement already satisfied: s3transfer<0.13.0,>=0.12.0 in /home/islam/.local/lib/python3.11/site-packages (from boto3>=1.35.74->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.10->pydantic-ai) (0.12.0)
# Requirement already satisfied: fastavro<2.0.0,>=1.9.4 in /home/islam/.local/lib/python3.11/site-packages (from cohere>=5.13.11->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.10->pydantic-ai) (1.10.0)
# Requirement already satisfied: httpx-sse==0.4.0 in /home/islam/.local/lib/python3.11/site-packages (from cohere>=5.13.11->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.10->pydantic-ai) (0.4.0)
# Requirement already satisfied: tokenizers<1,>=0.15 in /home/islam/.local/lib/python3.11/site-packages (from cohere>=5.13.11->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.10->pydantic-ai) (0.21.1)
# Requirement already satisfied: types-requests<3.0.0,>=2.0.0 in /home/islam/.local/lib/python3.11/site-packages (from cohere>=5.13.11->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.10->pydantic-ai) (2.32.0.20250328)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/islam/.local/lib/python3.11/site-packages (from google-auth>=2.36.0->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.10->pydantic-ai) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/islam/.local/lib/python3.11/site-packages (from google-auth>=2.36.0->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.10->pydantic-ai) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/islam/.local/lib/python3.11/site-packages (from google-auth>=2.36.0->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.10->pydantic-ai) (4.9.1)
# Requirement already satisfied: colorama>=0.4 in /home/islam/anaconda3/envs/py311/lib/python3.11/site-packages (from griffe>=1.3.2->pydantic-ai-slim==0.1.10->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.10->pydantic-ai) (0.4.6)
# Requirement already satisfied: mdurl~=0.1 in /home/islam/.local/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich>=13->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.10->pydantic-ai) (0.1.2)
# Requirement already satisfied: pydantic-settings>=2.5.2 in /home/islam/.local/lib/python3.11/site-packages (from mcp>=1.6.0->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.10->pydantic-ai) (2.9.1)
# Requirement already satisfied: python-multipart>=0.0.9 in /home/islam/.local/lib/python3.11/site-packages (from mcp>=1.6.0->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.10->pydantic-ai) (0.0.20)
# Requirement already satisfied: sse-starlette>=1.6.1 in /home/islam/.local/lib/python3.11/site-packages (from mcp>=1.6.0->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.10->pydantic-ai) (2.3.4)
# Requirement already satisfied: starlette>=0.27 in /home/islam/.local/lib/python3.11/site-packages (from mcp>=1.6.0->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.10->pydantic-ai) (0.46.2)
# Requirement already satisfied: uvicorn>=0.23.1 in /home/islam/.local/lib/python3.11/site-packages (from mcp>=1.6.0->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.10->pydantic-ai) (0.34.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/islam/.local/lib/python3.11/site-packages (from mistralai>=1.2.5->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.10->pydantic-ai) (2.9.0.post0)
# Requirement already satisfied: tqdm>4 in /home/islam/.local/lib/python3.11/site-packages (from openai>=1.75.0->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.10->pydantic-ai) (4.67.1)
# Requirement already satisfied: wcwidth in /home/islam/.local/lib/python3.11/site-packages (from prompt-toolkit>=3->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.10->pydantic-ai) (0.2.13)
# Requirement already satisfied: zipp>=3.20 in /home/islam/.local/lib/python3.11/site-packages (from importlib-metadata<8.7.0,>=6.0->opentelemetry-api>=1.28.0->pydantic-ai-slim==0.1.10->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.10->pydantic-ai) (3.21.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /home/islam/.local/lib/python3.11/site-packages (from pyasn1-modules>=0.2.1->google-auth>=2.36.0->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.10->pydantic-ai) (0.6.1)
# Requirement already satisfied: python-dotenv>=0.21.0 in /home/islam/.local/lib/python3.11/site-packages (from pydantic-settings>=2.5.2->mcp>=1.6.0->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.10->pydantic-ai) (1.1.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /home/islam/.local/lib/python3.11/site-packages (from tokenizers<1,>=0.15->cohere>=5.13.11->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.10->pydantic-ai) (0.30.2)
# Requirement already satisfied: click>=7.0 in /home/islam/anaconda3/envs/py311/lib/python3.11/site-packages (from uvicorn>=0.23.1->mcp>=1.6.0->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.10->pydantic-ai) (8.1.8)
# Requirement already satisfied: filelock in /home/islam/.local/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<1,>=0.15->cohere>=5.13.11->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.10->pydantic-ai) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/islam/.local/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<1,>=0.15->cohere>=5.13.11->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.1.10->pydantic-ai) (2025.3.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import re
import os
from dataclasses import dataclass
from typing import Any
from datetime import datetime
import gradio as gr
import nest_asyncio
from dotenv import load_dotenv
from httpx import AsyncClient
from google_auth_oauthlib.flow import InstalledAppFlow
from googleapiclient.discovery import build
from google.auth.transport.requests import Request
from google.oauth2.credentials import Credentials
from datetime import datetime
from pydantic_ai import Agent, ModelRetry, RunContext
from pydantic_ai.models.openai import OpenAIModel
from pydantic_ai.providers.openai import OpenAIProvider
from datetime import datetime, timedelta
from google_auth_oauthlib.flow import InstalledAppFlow
from googleapiclient.discovery import build
from google.auth.transport.requests import Request
from google.oauth2.credentials import Credentials
from googlesearch import search
# ---------- Setup ----------
load_dotenv()
nest_asyncio.apply()

ollama_model = OpenAIModel(
    model_name='qwen2.5:latest',
    provider=OpenAIProvider(base_url='http://localhost:11434/v1')
)


@dataclass
class Deps:
    client: AsyncClient
    weather_api_key: str | None


agent = Agent(
    ollama_model,
    system_prompt=(
        'You are a smart assistant. You can access tools:\n'
        '- get_weather(city: str): Returns weather info.\n'
        '- calculate_expression(expression: str): Evaluates math.\n'
        '- tripPlanner(start_date: date, end_date: date, location: str): Trip planner.\n'
        '- add_to_google_calendar(summary, location, start_date, end_date): Adds to Google Calendar.\n'
        '- get_upcoming_events(start_date, end_date): Retrieves upcoming events.\n'
        '- search(query: str): Searches the web and gives a structured response.\n'
        'Use these tools when the user requests relevant information.'
    ),
    deps_type=Deps,
    retries=2,
    instrument=True,
)


trip_agent = Agent(
    ollama_model,
    output_type=str,)

# %%
import httpx


async def fetch_wikipedia_summary(location: str) -> str:
    try:
        async with httpx.AsyncClient() as client:
            response = await client.get(f"https://en.wikipedia.org/api/rest_v1/page/summary/{location}")
            if response.status_code == 200:
                return response.json().get("extract", "")
    except:
        return ""


def is_valid_expression(expr: str) -> bool:
    return bool(re.fullmatch(r"[0-9+\-*/().\\s]+", expr.strip()))


@agent.tool
async def get_weather(context: RunContext[Deps], city: str) -> str:
    """
    Fetches the current weather temperature for a specified city using the WeatherAPI.

    Args:
        city (str): The name of the city for which to fetch the weather.

    Returns:
        str: A message containing the current temperature in Celsius for the specified city, 
             or an error message if the city is not found or the API response is invalid.

    Example:
        >>> get_weather("Dhaka")
        'The current temperature in Dhaka is 30°C.'
    """
    if not context.deps.weather_api_key:
        raise ValueError("Weather API key is not set.")

    url = f"http://api.weatherapi.com/v1/current.json?key={context.deps.weather_api_key}&q={city}"
    response = await context.deps.client.get(url)
    data = response.json()
    print(f"Tool Get_weather: {data}")
    return f"The weather in {city} is {data['current']['temp_c']}\u00b0C."


@agent.tool_plain
async def calculate_expression(expression: str) -> str:
    """
    Evaluates a mathematical expression provided as a string.

    Args:
        expression (str): A string containing a mathematical expression to be evaluated.

    Returns:
        str: The result of the evaluation as a string, or an error message if the evaluation fails.

    Example:
        >>> calculate_expression("2 + 3 * 4")
        '14'
        >>> calculate_expression("10 / 0")
        'Calculation error: division by zero'
    """
    if not is_valid_expression(expression):
        raise ModelRetry('This does not look like a valid math expression.')
    try:
        print(f"Tool Calculate_expression: {expression}")
        return str(eval(expression))
    except Exception as e:
        return f"Calculation error: {e}"


@agent.tool_plain
async def tripPlanner(start_date: str, end_date: str, location: str) -> str:
    try:
        start = datetime.strptime(start_date, "%Y-%m-%d")
        end = datetime.strptime(end_date, "%Y-%m-%d")
        duration = (end - start).days + 1
        today = datetime.now().date()
        if start.date() < today:
            return "❌ The start date cannot be in the past."
        if end.date() < today:
            return "❌ The end date cannot be in the past."
        if end.date() <= start.date():
            return "❌ The end date must be after the start date."

        if duration <= 0:
            return "Invalid date range. Please check the start and end dates."

        contexts = await fetch_wikipedia_summary(location)

        prompt = (
            f"Context:\n{contexts}\n\n"
            f"I'm planning a {duration}-day trip to {location}. "
            f"Give me the following:\n"
            f"- Famous attractions\n"
            f"- Food recommendations\n"
            f"- Fun activities\n"
            f"- A fun fact\n"
            f"- Estimated budget (in local currency)\n"
            f"Keep it concise and friendly."
        )

        response = await trip_agent.run(
            prompt,
        )
        print(f"toolPlanner")
        return response.output

    except ValueError:
        return "Please use YYYY-MM-DD format for dates."
    except Exception as e:
        return f"Error: {e}"


@agent.tool_plain
async def add_to_google_calendar(summary: str, location: str, start_date: str, end_date: str) -> str:
    """
    Adds an event to Google Calendar with the provided details.

    Args:
        summary (str): The title/summary of the event.
        location (str): The location of the event.
        start_date (str): The start date of the event in 'YYYY-MM-DD' format.
        end_date (str): The end date of the event in 'YYYY-MM-DD' format.

    Returns:
        str: A confirmation message with the event link, or an error message.

    Example:
        >>> add_to_google_calendar("Trip to Sylhet", "Sylhet", "2024-06-01", "2024-06-05")
        '✅ Trip added to your Google Calendar: https://calendar.google.com/event?eid=...'
    """

    # Validate dates are not in the past
    current_datetime = datetime.now()

    # Parse start and end dates
    start_datetime = datetime.strptime(
        f'{start_date}T09:00:00', '%Y-%m-%dT%H:%M:%S')
    end_datetime = datetime.strptime(
        f'{end_date}T17:00:00', '%Y-%m-%dT%H:%M:%S')

    if start_datetime < current_datetime:
        return "❌ The start date cannot be in the past."
    if end_datetime < current_datetime:
        return "❌ The end date cannot be in the past."
    if end_datetime <= start_datetime:
        return "❌ The end date must be after the start date."

    # Google Calendar API setup
    SCOPES = ['https://www.googleapis.com/auth/calendar.events']

    creds = None
    if os.path.exists('token.json'):
        creds = Credentials.from_authorized_user_file('token.json', SCOPES)
    if not creds or not creds.valid:
        if creds and creds.expired and creds.refresh_token:
            creds.refresh(Request())
        else:
            flow = InstalledAppFlow.from_client_secrets_file(
                'credentials.json', SCOPES)
            creds = flow.run_local_server(port=0)
        with open('token.json', 'w') as token:
            token.write(creds.to_json())

    service = build('calendar', 'v3', credentials=creds)

    event = {
        'summary': summary,
        'location': location,
        'start': {
            'dateTime': f'{start_date}T09:00:00',
            'timeZone': 'Asia/Dhaka',
        },
        'end': {
            'dateTime': f'{end_date}T17:00:00',
            'timeZone': 'Asia/Dhaka',
        },
        'description': f'Trip to {location} from {start_date} to {end_date}. Auto-generated by AI.'
    }

    # Create the event on Google Calendar
    event = service.events().insert(calendarId='primary', body=event).execute()
    print(f"Event created: {event.get('htmlLink')}")

    return f"✅ Trip added to your Google Calendar: {event.get('htmlLink')}"


@agent.tool_plain
async def get_upcoming_events(start_date=None, end_date=None):
    """
    Retrieves upcoming Google Calendar events within a given date range if given else retrives next one month events from today.

    Args:
        start_date (str, optional): Start date in 'YYYY-MM-DD' format or 'today'. Defaults to today.
        end_date (str, optional): End date in 'YYYY-MM-DD' format. Defaults to 1 month from today.

    Returns:
        str: A list of upcoming events with date, time, and summary.

    Example:
        >>> get_upcoming_events("2024-06-01", "2024-06-15")
        '📅 June 2, 10:00 AM - Team Meeting\n📅 June 5, 3:00 PM - Doctor Appointment\n...'
    """

    SCOPES = ['https://www.googleapis.com/auth/calendar.readonly']

    # Auth setup
    creds = None
    if os.path.exists('token.json'):
        creds = Credentials.from_authorized_user_file('token.json', SCOPES)
    if not creds or not creds.valid:
        if creds and creds.expired and creds.refresh_token:
            creds.refresh(Request())
        else:
            flow = InstalledAppFlow.from_client_secrets_file(
                'credentials.json', SCOPES)
            creds = flow.run_local_server(port=0)
        with open('token.json', 'w') as token:
            token.write(creds.to_json())

    service = build('calendar', 'v3', credentials=creds)

    # Default date range: today to 30 days later
    now = datetime.utcnow()

    if start_date == "today" or not start_date:
        time_min = now
    else:
        time_min = datetime.strptime(start_date, '%Y-%m-%d')

    if end_date:
        time_max = datetime.strptime(end_date, '%Y-%m-%d')
    else:
        time_max = now + timedelta(days=30)

    time_min_str = time_min.isoformat() + 'Z'
    time_max_str = time_max.isoformat() + 'Z'

    # Fetch events
    events_result = service.events().list(
        calendarId='primary',
        timeMin=time_min_str,
        timeMax=time_max_str,
        singleEvents=True,
        orderBy='startTime'
    ).execute()

    events = events_result.get('items', [])

    if not events:
        return "📭 No upcoming events found in the selected date range."

    result = []
    for event in events:
        start = event['start'].get('dateTime', event['start'].get('date'))
        start_dt = datetime.fromisoformat(start.replace('Z', '+00:00'))
        start_formatted = start_dt.strftime("📅 %B %d, %I:%M %p")
        summary = event.get('summary', '(No Title)')
        result.append(f"{start_formatted} - {summary}")

    print(f"Upcoming events:")
    return "\n".join(result)
'''
@agent.tool_plain
async def searchWeb(query: str) -> str:
    """
    Searches for a query using Google Search and returns the top 5 results with titles and descriptions.

    Args:
        query (str): The search query.

    Returns:
        str: Titles, URLs, and descriptions of the top 5 search results.
    """
    try:
        results = list(search(query, num_results=5, advanced=True))
        if results:
            print(f"Tool SearchWeb: {results}")
            formatted = "\n\n".join(
                f"{i+1}. {res.title}\n{res.url}\n{res.description}" for i, res in enumerate(results)
            )
            return f"Top 5 results:\n\n{formatted}"
        else:
            return "No results found."
    except Exception as e:
        return f"Error during search: {e}"'''

@agent.tool_plain
async def searchWeb(query: str) -> str:
    '''
    Searches for a query using Google Search and returns the top 5 results with titles and descriptions.'''
    try:
        apikey = os.getenv("cloudapi")
        search_engine_id = os.getenv("searchengine")
        async with httpx.AsyncClient() as client:
            response = await client.get(
                f"https://www.googleapis.com/customsearch/v1?key={apikey}&cx={search_engine_id}&q={query}"
            )
        data = response.json()
        if "items" in data:
            results = data["items"][:5]  # Limit to top 5 results
            formatted = "\n\n".join(
                f"{i+1}. {res['title']}\n{res['link']}\n{res['snippet']}" for i, res in enumerate(results)
            )
            print(f"Tool SearchWeb: {results}")
            return f"Top 5 results:\n\n{formatted}"
        else:
            return "No results found."
    except Exception as e:
        return f"Error during search: {e}"

# %%
# ---------- Gradio Setup ----------
chat_messages = []  # Global message history


async def chat_with_agent(message, history):
    weather_key = os.getenv('weatherapicom_API_KEY')
    async with AsyncClient() as client:
        deps = Deps(client=client, weather_api_key=weather_key)
        global chat_messages

        # Prepare conversation
        if not chat_messages:
            result = await agent.run(message, deps=deps)
        else:
            result = await agent.run(message, deps=deps, message_history=chat_messages)

        chat_messages = result.new_messages()

        # Process the result to check if a tool was called and format the output
        tool_output = result.output

        # If no tool was called, just return the assistant's output
        formatted_response = f"🤖 {tool_output}"

        return "", history + [[message, formatted_response]]


def reset_chat():
    global chat_messages
    chat_messages = []
    return [], ""


with gr.Blocks() as demo:
    gr.Markdown("## 🤖 Smart Assistant with Tools")

    chatbot = gr.Chatbot()
    msg = gr.Textbox(label="Ask me something...")
    clear = gr.Button("Clear Chat")

    msg.submit(chat_with_agent, [msg, chatbot], [msg, chatbot])
    clear.click(reset_chat, outputs=[chatbot, msg])
    demo.unload(reset_chat)

# ---------- Launch ----------
demo.launch(share=True)
# Out:
# /tmp/ipykernel_2887214/3320054510.py:37: UserWarning: You have not specified a value for the `type` parameter. Defaulting to the 'tuples' format for chatbot messages, but this is deprecated and will be removed in a future version of Gradio. Please set type='messages' instead, which uses openai-style dictionaries with 'role' and 'content' keys.
#   chatbot = gr.Chatbot()
# * Running on local URL:  http://127.0.0.1:7860
# * Running on public URL: https://03975b0172e8e36669.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://03975b0172e8e36669.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Tool SearchWeb: [{'kind': 'customsearch#result', 'title': 'Bangladesh - Wikipedia', 'htmlTitle': '<b>Bangladesh</b> - Wikipedia', 'link': 'https://en.wikipedia.org/wiki/Bangladesh', 'displayLink': 'en.wikipedia.org', 'snippet': 'It is the eighth-most populous country in the world and among the most densely populated with a population of over 171 million within an area of 148,460 square\xa0...', 'htmlSnippet': 'It is the eighth-most populous country in the world and among the most densely populated with a population of over 171 million within an area of 148,460 square&nbsp;...', 'formattedUrl': 'https://en.wikipedia.org/wiki/Bangladesh', 'htmlFormattedUrl': 'https://en.wikipedia.org/wiki/<b>Bangladesh</b>', 'pagemap': {'hcard': [{'fn': "People's Republic of Bangladesh"}], 'metatags': [{'referrer': 'origin', 'og:image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/f/f9/Flag_of_Bangladesh.svg/1200px-Flag_of_Bangladesh.svg.png', 'theme-color': '#eaecf0', 'og:image:width': '1200', 'og:type': 'website', 'viewport': 'width=device-width, initial-scale=1.0, user-scalable=yes, minimum-scale=0.25, maximum-scale=5.0', 'og:title': 'Bangladesh - Wikipedia', 'og:image:height': '720', 'format-detection': 'telephone=no'}]}}, {'kind': 'customsearch#result', 'title': 'Bangladesh | History, Capital, Map, Flag, Population, Pronunciation ...', 'htmlTitle': '<b>Bangladesh</b> | History, Capital, Map, Flag, Population, Pronunciation ...', 'link': 'https://www.britannica.com/place/Bangladesh', 'displayLink': 'www.britannica.com', 'snippet': '3 days ago ... Bangladesh, country of South Asia, located in the delta of the Padma (Ganges [Ganga]) and Jamuna (Brahmaputra) rivers in the northeastern part of the Indian\xa0...', 'htmlSnippet': '3 days ago <b>...</b> <b>Bangladesh</b>, country of South Asia, located in the delta of the Padma (Ganges [Ganga]) and Jamuna (Brahmaputra) rivers in the northeastern part of the Indian&nbsp;...', 'formattedUrl': 'https://www.britannica.com/place/Bangladesh', 'htmlFormattedUrl': 'https://www.britannica.com/place/<b>Bangladesh</b>', 'pagemap': {'cse_thumbnail': [{'src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQ0lpIFHDIBXjWH4rjoGFpau-jpBgXwHWDsdFsjKW0r_GzhS84NRa5Elt0&s', 'width': '290', 'height': '174'}], 'metatags': [{'og:image': 'https://cdn.britannica.com/67/6267-050-8A26DFEE/Flag-Bangladesh.jpg', 'twitter:card': 'summary_large_image', 'og:type': 'ARTICLE', 'og:site_name': 'Encyclopedia Britannica', 'og:title': 'Bangladesh | History, Capital, Map, Flag, Population, Pronunciation, & Facts | Britannica', 'og:image:type': 'image/jpeg', 'og:description': 'Bangladesh is a country of South Asia, located in the delta of the Padma (Ganges) and Jamuna (Brahmaputra) rivers in the northeastern part of the Indian subcontinent. It is one of the most densely populated countries in the world, and its people are predominantly Muslim. Its capital is Dhaka.', 'twitter:image': 'https://cdn.britannica.com/67/6267-050-8A26DFEE/Flag-Bangladesh.jpg', 'last-modified': '2025-05-06', 'fb:app_id': '1887621861548296', 'twitter:site': '@britannica', 'viewport': 'width=device-width, initial-scale=1.0', 'twitter:description': 'Bangladesh is a country of South Asia, located in the delta of the Padma (Ganges) and Jamuna (Brahmaputra) rivers in the northeastern part of the Indian subcontinent. It is one of the most densely populated countries in the world, and its people are predominantly Muslim. Its capital is Dhaka.', 'og:url': 'https://www.britannica.com/place/Bangladesh'}], 'cse_image': [{'src': 'https://cdn.britannica.com/67/6267-050-8A26DFEE/Flag-Bangladesh.jpg'}]}}, {'kind': 'customsearch#result', 'title': 'Bangladesh | Education Cannot Wait', 'htmlTitle': '<b>Bangladesh</b> | Education Cannot Wait', 'link': 'https://www.educationcannotwait.org/our-investments/where-we-work/bangladesh', 'displayLink': 'www.educationcannotwait.org', 'snippet': 'Bringing hope and opportunity through quality education to Rohingya refugees and ...
# Tool SearchWeb: [{'kind': 'customsearch#result', 'title': 'Kurt Vile: Home', 'htmlTitle': '<b>Kurt</b> Vile: Home', 'link': 'https://www.kurtvile.com/', 'displayLink': 'www.kurtvile.com', 'snippet': 'New Release. Back To Moon Beach. Listen Now. Music. Previous\xa0...', 'htmlSnippet': '<b>New</b> Release. Back To Moon Beach. Listen Now. Music. Previous&nbsp;...', 'formattedUrl': 'https://www.kurtvile.com/', 'htmlFormattedUrl': 'https://www.kurtvile.com/', 'pagemap': {'MusicEvent': [{'name': 'Monday July 28th 2025 - The Fillmore Detroit', 'startDate': '2025-07-28T19:00:00'}, {'name': 'Tuesday July 29th 2025 - The Fillmore Detroit', 'startDate': '2025-07-29T19:00:00'}, {'name': 'Thursday July 31st 2025 - Palace Theatre', 'startDate': '2025-07-31T19:00:00'}, {'name': 'Friday August 1st 2025 - Palace Theatre', 'startDate': '2025-08-01T19:00:00'}, {'name': 'Saturday August 2nd 2025 - SPACE', 'startDate': '2025-08-02T19:00:00'}, {'name': 'Sunday August 3rd 2025 - The Vogue', 'startDate': '2025-08-03T19:00:00'}, {'name': 'Friday June 13th 2025 - Encore Theater at Wynn', 'startDate': '2025-06-13T19:00:00'}, {'name': 'Thursday February 5th 2026 - Modest Mouse Cruise 2026', 'startDate': '2026-02-05T19:00:00'}, {'name': 'Saturday June 14th 2025 - Encore Theater at', 'startDate': '2025-06-14T19:00:00'}, {'name': 'Saturday June 14th 2025 - Encore Theater at', 'startDate': '2025-06-14T19:00:00'}, {'name': 'Monday June 16th 2025 - The Van Buren', 'startDate': '2025-06-16T19:00:00'}, {'name': 'Tuesday June 17th 2025 - The Van Buren', 'startDate': '2025-06-17T19:00:00'}, {'name': 'Wednesday June 18th 2025 - Belly Up Tavern', 'startDate': '2025-06-18T19:00:00'}, {'name': 'Thursday June 19th 2025 - The Observatory', 'startDate': '2025-06-19T19:00:00'}, {'name': 'Friday June 20th 2025 - Hollywood Palladium', 'startDate': '2025-06-20T19:00:00'}, {'name': 'Saturday June 21st 2025 - Hollywood Palladium', 'startDate': '2025-06-21T19:00:00'}, {'name': 'Monday June 23rd 2025 - Paramount Theatre', 'startDate': '2025-06-23T19:00:00'}, {'name': 'Tuesday June 24th 2025 - Paramount Theatre', 'startDate': '2025-06-24T19:00:00'}, {'name': 'Thursday June 26th 2025 - The Orpheum', 'startDate': '2025-06-26T19:00:00'}, {'name': 'Friday June 27th 2025 - The Orpheum', 'startDate': '2025-06-27T19:00:00'}, {'name': 'Saturday June 28th 2025 - Knitting Factory', 'startDate': '2025-06-28T19:00:00'}, {'name': 'Sunday June 29th 2025 - Knitting Factory Concert House', 'startDate': '2025-06-29T19:00:00'}, {'name': 'Tuesday July 8th 2025 - MTelus (Metropolis)', 'startDate': '2025-07-08T19:00:00'}, {'name': 'Wednesday July 9th 2025 - MTelus (Metropolis)', 'startDate': '2025-07-09T19:00:00'}, {'name': "Thursday July 10th 2025 - Festival d'été", 'startDate': '2025-07-10T12:00:00'}, {'name': 'Friday July 11th 2025 - Danforth Music Hall', 'startDate': '2025-07-11T19:00:00'}, {'name': 'Saturday July 12th 2025 - Ottawa Bluesfest 2025', 'startDate': '2025-07-12T12:00:00'}, {'name': 'Sunday July 13th 2025 - Asbury Hall', 'startDate': '2025-07-13T19:00:00'}, {'name': 'Tuesday July 15th 2025 - Brooklyn Paramount', 'startDate': '2025-07-15T19:00:00'}, {'name': 'Wednesday July 16th 2025 - Brooklyn Paramount', 'startDate': '2025-07-16T19:00:00'}, {'name': 'Saturday July 19th 2025 - MGM Music Hall at Fenway', 'startDate': '2025-07-19T19:00:00'}, {'name': "Sunday July 20th 2025 - Toad's Place", 'startDate': '2025-07-20T19:00:00'}, {'name': 'Monday July 21st 2025 - State Theatre', 'startDate': '2025-07-21T19:00:00'}, {'name': 'Thursday June 12th 2025 - Rialto Theatre', 'startDate': '2025-06-12T19:00:00'}, {'name': 'Tuesday July 22nd 2025 - The Fillmore Philadelphia', 'startDate': '2025-07-22T19:00:00'}, {'name': 'Wednesday July 23rd 2025 - The Fillmore Philadelphia', 'startDate': '2025-07-23T19:00:00'}, {'name': 'Friday July 25th 2025 - The Anthem', 'startDate': '2025-07-25T19:00:00'}, {'name': 'Saturday July 26th 2025 - The Anthem', 'startDate': '2025-07-26T19:00:00'}], 'metatags': [{'og:typ ...
